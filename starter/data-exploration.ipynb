# %%
import pandas as pd

# %%
df = pd.read_csv('supermarket.csv')

# %%
df.head()
# Out:
#    store_id  store_area  items_available  daily_customer_count  store_sales
# 0         1        1659             1961                   530        66490
# 1         2        1461             1752                   210        39820
# 2         3        1340             1609                   720        54010
# 3         4        1451             1748                   620        53730
# 4         5        1770             2111                   450        46620

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store_id              896 non-null    int64
#  1   store_area            896 non-null    int64
#  2   items_available       896 non-null    int64
#  3   daily_customer_count  896 non-null    int64
#  4   store_sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
# import seaborn
import seaborn as sns
# set standard plot type as seaborn plot
sns.set()
# import matplotlib
import matplotlib.pyplot as plt
# write command for plots to appear in jupyter cells automatically
# %matplotlib inline
import numpy as np

# %%
plt.figure(figsize=(12,4))

plt.title("Available Items", fontsize=16)

sns.boxplot(x=df['items_available'])

plt.xlabel("Items Available", fontsize=14);

# %%
df['store_sales'].describe()
# Out:
# count       896.000000
# mean      59351.305804
# std       17190.741895
# min       14920.000000
# 25%       46530.000000
# 50%       58605.000000
# 75%       71872.500000
# max      116320.000000
# Name: store_sales, dtype: float64

# %%
sns.pairplot(df)

# %%
top_data=df.sort_values('store_sales', ascending=False).head(10)

# %%
df.nlargest(n=10, columns=['store_sales', 'daily_customer_count'])
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 649       650        1989             2414                   860       116320
# 868       869        1775             2104                   980       105150
# 432       433        1365             1638                   680       102920
# 408       409        1303             1587                  1310       102310
# 758       759        1486             1758                   820       101820
# 557       558        1137             1374                   700       101780
# 866       867        1565             1854                   900       100900
# 166       167        1465             1763                   680        99570
# 692       693        1548             1858                   480        99480
# 871       872        1800             2158                  1100        98260

# %%
df.mean(axis='index')
# Out:
# store_id                  448.500000
# store_area               1485.409598
# items_available          1782.035714
# daily_customer_count      786.350446
# store_sales             59351.305804
# dtype: float64

# %%
df['store_sales'].nlargest(n=10)
# Out:
# 649    116320
# 868    105150
# 432    102920
# 408    102310
# 758    101820
# 557    101780
# 866    100900
# 166     99570
# 692     99480
# 871     98260
# Name: store_sales, dtype: int64

# %%
df['store_sales'].nsmallest(n=10)
# Out:
# 31     14920
# 852    16370
# 775    17670
# 593    20270
# 352    21300
# 725    21470
# 372    21650
# 277    21750
# 252    21830
# 670    22310
# Name: store_sales, dtype: int64

# %%
data['avg_sale_cust'] = (data['store_sales']/ data['daily_customer_count']).round(2)

data.head(10)
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales  \
# 649       650        1989             2414                   860       116320
# 868       869        1775             2104                   980       105150
# 432       433        1365             1638                   680       102920
# 408       409        1303             1587                  1310       102310
# 758       759        1486             1758                   820       101820
# 557       558        1137             1374                   700       101780
# 866       867        1565             1854                   900       100900
# 166       167        1465             1763                   680        99570
# 692       693        1548             1858                   480        99480
# 871       872        1800             2158                  1100        98260
#
#      avg_sale_cust
# 649         135.26
# 868         107.30
# 432         151.35
# 408          78.10
# ...

# %%
df.head()
# Out:
#    store_id  store_area  items_available  daily_customer_count  store_sales
# 0         1        1659             1961                   530        66490
# 1         2        1461             1752                   210        39820
# 2         3        1340             1609                   720        54010
# 3         4        1451             1748                   620        53730
# 4         5        1770             2111                   450        46620

# %%
data.tail()
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales  \
# 557       558        1137             1374                   700       101780
# 866       867        1565             1854                   900       100900
# 166       167        1465             1763                   680        99570
# 692       693        1548             1858                   480        99480
# 871       872        1800             2158                  1100        98260
#
#      avg_sale_cust
# 557         145.40
# 866         112.11
# 166         146.43
# 692         207.25
# 871          89.33

# %%
sales_df = df[['store_sales','store_id']].copy()
print(sales_df)
# Out:
#      store_sales  store_id
# 0          66490         1
# 1          39820         2
# 2          54010         3
# 3          53730         4
# 4          46620         5
# ..           ...       ...
# 891        66390       892
# 892        82080       893
# 893        76440       894
# 894        96610       895
# 895        54340       896
#
# [896 rows x 2 columns]

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   store_sales  896 non-null    int64
#  1   store_id     896 non-null    int64
# dtypes: int64(2)
# memory usage: 14.1 KB

# %%
print(top_data)
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 649       650        1989             2414                   860       116320
# 868       869        1775             2104                   980       105150
# 432       433        1365             1638                   680       102920
# 408       409        1303             1587                  1310       102310
# 758       759        1486             1758                   820       101820
# 557       558        1137             1374                   700       101780
# 866       867        1565             1854                   900       100900
# 166       167        1465             1763                   680        99570
# 692       693        1548             1858                   480        99480
# 871       872        1800             2158                  1100        98260

# %%
bottom_data=df.sort_values('store_sales', ascending=True).head(10)
print(bottom_data)
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 31         32        1250             1508                   990        14920
# 852       853        1477             1790                   880        16370
# 775       776        1537             1877                   660        17670
# 593       594        1624             1946                   870        20270
# 352       353        1397             1686                   850        21300
# 725       726        1445             1734                   900        21470
# 372       373        1876             2254                  1340        21650
# 277       278        1572             1869                  1030        21750
# 252       253        1583             1907                   680        21830
# 670       671        1461             1739                  1250        22310

# %%
top_data.describe()
# Out:
#          store_id   store_area  items_available  daily_customer_count  \
# count   10.000000    10.000000        10.000000               10.0000
# mean   627.700000  1543.300000      1850.800000              851.0000
# std    235.705584   254.460235       304.461565              238.4417
# min    167.000000  1137.000000      1374.000000              480.0000
# 25%    464.250000  1390.000000      1668.000000              685.0000
# 50%    671.500000  1517.000000      1808.500000              840.0000
# 75%    840.000000  1722.500000      2042.500000              960.0000
# max    872.000000  1989.000000      2414.000000             1310.0000
#
#          store_sales
# count      10.000000
# mean   102851.000000
# std      5123.140205
# min     98260.000000
# 25%     99902.500000
# 50%    101800.000000
# 75%    102767.500000
# max    116320.000000

# %%
bottom_data.describe()
# Out:
#          store_id   store_area  items_available  daily_customer_count  \
# count   10.000000    10.000000        10.000000             10.000000
# mean   490.900000  1522.200000      1831.000000            945.000000
# std    270.013354   164.468707       196.185287            218.746429
# min     32.000000  1250.000000      1508.000000            660.000000
# 25%    296.750000  1449.000000      1735.250000            855.000000
# 50%    483.500000  1507.000000      1829.500000            890.000000
# 75%    712.250000  1580.250000      1899.500000           1020.000000
# max    853.000000  1876.000000      2254.000000           1340.000000
#
#         store_sales
# count     10.000000
# mean   19954.000000
# std     2641.229512
# min    14920.000000
# 25%    18320.000000
# 50%    21385.000000
# 75%    21725.000000
# max    22310.000000

# %%
print(top_data.sum())
# Out:
# store_id                   6277
# store_area                15433
# items_available           18508
# daily_customer_count       8510
# store_sales             1028510
# dtype: int64

# %%
print(bottom_data.sum())
# Out:
# store_id                  4909
# store_area               15222
# items_available          18310
# daily_customer_count      9450
# store_sales             199540
# dtype: int64

# %%
print(df.sum())
# Out:
# store_id                  401856
# store_area               1330927
# items_available          1596704
# daily_customer_count      704570
# store_sales             53178770
# dtype: int64
